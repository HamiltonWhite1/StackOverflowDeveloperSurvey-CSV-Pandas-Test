# %%
import pandas as pd ###Importing pandas

# %%
df = pd.read_csv('survey_results_public.csv') ###importing csv files into the code file
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.shape ###checks how many rows and columns
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
high_sal = (df['CompTotal'] > 70000) & (df['LanguageHaveWorkedWith'] == 'Python') & df['LearnCode'].str.contains("Coding Bootcamp", na=False)

# %%
df.loc[high_sal]
# Out:
#        ResponseId                                         MainBranch  \
# 1475         1476                     I am a developer by profession
# 6449         6450                     I am a developer by profession
# 13928       13929                     I am a developer by profession
# 14028       14029                     I am a developer by profession
# 22117       22118                     I am a developer by profession
# 25011       25012                     I am a developer by profession
# 31283       31284  I am not primarily a developer, but I write co...
# 32543       32544                     I am a developer by profession
# 35406       35407                     I am a developer by profession
# 39985       39986                     I am a developer by profession
# 43588       43589                     I am a developer by profession
# 49498       49499                     I am a developer by profession
# 53009       53010                     I am a developer by profession
# ...

# %%
df.rename(columns={'RESPONSEID': 'Response', 'COUNTRY': 'PlaceOfResidence'}, inplace=True) ###renaming columns

# %%
df.loc[1475, ['EMPLOYMENT', 'LEARNCODE']] = ['PUMPKINS', 'CHICKENS'] ###changing the employment and learncode row values to pumpkins and chickens

# %%
df.loc[1475, 'EMPLOYMENT'] = 'CHEESE' ###changing the employment row of the response at 1475 to 'CHEESE'

# %%
df['EMPLOYMENT'].map({'Employed full-time': 'Bobs'}) ###this changes all answers of "Employed full-time" in the Employment column to "Bobs"
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 83434    NaN
# 83435    NaN
# 83436    NaN
# 83437    NaN
# 83438    NaN
# Name: EMPLOYMENT, Length: 83439, dtype: object

# %%
df['Working-Where'] = df['EMPLOYMENT'] + ' ' + df['PlaceOfResidence'] ###Creating a new column called Working-where that includes country and type of employment
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PlaceOfResidence'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.drop(columns=['SEXUALITY', 'ACCESSIBILITY']) ###Dropping the sexuality and accessibility columns

# %%
df['Working-Where'].str.split(' ', expand=True)

# %%
df.append({'first': 'Tony'}, ignore_index=True) ###Appending a single row of data

# %%
df.sort_values(by='EMPLOYMENT', ascending=False)

# %%
df.sort_values(by=['Country', 'CompTotal'], ascending=[True, False], inplace=True) ###Sorting values by Country and CompTotal, and setting Country to Aplhabetical ascending order

# %%
df

# %%
df['CompTotal'].head(10)

# %%
df['CompTotal'].median() ###Pulls median from the CompTotal column

# %%
df.median() ###Pulls median for all numerical values in the dataframe

# %%
df.describe() ###50% is the median quantile

# %%
df['CompTotal'].count()

# %%
df['Trans'].value_counts(normalize=True)

# %%
##Group-by is done by splitting, combining, and grouping

# %%
df['Country'].value_counts()

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
filt = df['Country'] == 'Germany' ###Running a filter to find country of choice...
df.loc[filt]['Trans'].value_counts() ###then counting the value of responses to the Trans question in the survey

# %%
country_grp['LearnCode'].value_counts().loc['United States of America'].head(20)

# %%
country_grp['CompTotal'].agg(['median', 'mean']).loc['United States of America']
